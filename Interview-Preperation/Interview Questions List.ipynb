# %% [markdown]
# # Python Fundamentals

# %% [markdown]
# ❓ 1. What is the difference between a list and a tuple?
#
# Answer: list is mutable, tuple is immutable.
#
# ❓ 2. What is a dictionary and when do we use it?
#
# Answer: key-value data storage → JSON, config, mapping.
#
# ❓ 3. What is the difference between “==” and “is”?
#
# Answer:
#
# == compares values
#
# is compares memory reference
#
# ❓ 4. What is list comprehension?
#
# Answer: A concise way to generate lists.

# %% [markdown]
# # Numpy & Pandas

# %% [markdown]
# ❓ 1. What is the difference between loc and iloc?
#
# loc → label-based
# iloc → index-based
#
# ❓ 2. How do you handle missing values?
#
# drop
#
# fillna (mean/median/mode)
#
# forward/backward fill
#
# ❓ 3. Why is NumPy faster than Python lists?
#
# Because it uses:
#
# contiguous memory
#
# C-level optimized operations
#
# vectorization
#
# ❓ 4. How does groupby work internally?
#
# It splits → applies function → combines results.
