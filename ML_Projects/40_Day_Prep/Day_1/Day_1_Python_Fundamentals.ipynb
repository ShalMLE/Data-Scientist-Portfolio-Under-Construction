# %%
#Variables
x = 10
name = "Shalini"
is_data_scientist = False

# %% [raw]
# DataTypes
# | Type  | Example    | DS Use-case           |
# | ----- | ---------- | --------------------- |
# | int   | 5          | counts, IDs           |
# | float | 10.5       | numerical features    |
# | str   | "Netflix"  | text features         |
# | bool  | True/False | classifiers, flags    |
# | list  | [1,2,3]    | arrays                |
# | tuple | (1,2)      | immutable coordinates |
# | dict  | {"age":30} | JSON-like data        |
# | set   | {1,2,3}    | unique values         |

# %%
#Conditional Statements
age = 25
if age > 18:
    print("Adult")
else:
    print("Minor")
# Out:
# Adult

# %% [markdown]
# ### Loops

# %%
#For Loop
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#While Loop
i = 0
while i < 5:
    print(i)
    i += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### Functions

# %%
def greet(name):
    return f"Hello {name}"

greet("Shalini")
# Out:
# 'Hello Shalini'

# %% [markdown]
# ### List Comprehension

# %%
squares = [i*i for i in range(10)]
squares
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# ### Practice Task with Solution

# %% [markdown]
# Task 1
#
# Create variables for:
#
# Your name
#
# Your desired job role
#
# Years of experience
# Print them in a formatted sentence.

# %%
name = 'Shalini'
job_role = 'Data Scientist'
year_of_experience = 5
print (f'My name is {name}. I want to become a {job_role}. I have {year_of_experience} years of experience in the IT industry.')
# Out:
# My name is Shalini. I want to become a Data Scientist. I have 5 years of experience in the IT industry.

# %% [markdown]
# Task 2
#
# Write a program to check if a number is even or odd.

# %%
def check_num(num):
    if num % 2 == 0:
        print('Even')
    else:
        print('Odd')

# %%
check_num(5)
# Out:
# Odd

# %%
check_num(8)
# Out:
# Even

# %% [markdown]
# Task 3
#
# Given a list:
#
# nums = [1, 4, 7, 10, 13, 16]
#
# Use a loop to print:
#
#  :Only even numbers
#
#  :Only numbers > 10

# %%
nums = [1, 4, 7, 10, 13, 16]
for i in nums:
    if i % 2 == 0 and i > 10:
        print(i)
# Out:
# 16

# %% [markdown]
# Task 4:
#
# write a function square_list

# %%
def square_list(lst):
    print ([i*i for i in lst])

# %%
square_list([3,6,8])
# Out:
# [9, 36, 64]

# %% [markdown]
# Task 5
#
# Write a function to count vowels in a string.

# %%
def count_vowels(string):
    n = 0
    for i in string.lower():
        if i == 'a' or i == 'e' or i == 'i' or i == 'o' or i == 'u':
           n += 1 
    print(n)

# %%
count_vowels('I am a good girl')
# Out:
# 6

# %% [markdown]
# Task 6 (DS Important)
#
# Given:
#
# data = [10, 20, 30, 40, 50]
#
# Compute:
#
# sum
#
# min
#
# max
#
# average

# %%
data = [10, 20, 30, 40, 50]
print(sum(data))
print(min(data))
print(max(data))
print(sum(data) / len(data))
# Out:
# 150
# 10
# 50
# 30.0
